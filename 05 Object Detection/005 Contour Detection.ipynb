# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
demoImage=cv2.imread("../Computer-Vision-with-Python/DATA/internal_external.png",0)

# %%
plt.figure(figsize=(15,10))
plt.imshow(demoImage,cmap="gray")

# %%
contour,heirarchy=cv2.findContours(demoImage,cv2.RETR_CCOMP,cv2.CHAIN_APPROX_SIMPLE)

# %%
len(contour)
# Out:
# 22

# %%
# last index will tell about the contours 
#-1 to -1 first external contour
#0 is first internal contour and 5 is second
heirarchy
# Out:
# array([[[ 4, -1,  1, -1],
#         [ 2, -1, -1,  0],
#         [ 3,  1, -1,  0],
#         [-1,  2, -1,  0],
#         [21,  0,  5, -1],
#         [ 6, -1, -1,  4],
#         [ 7,  5, -1,  4],
#         [ 8,  6, -1,  4],
#         [ 9,  7, -1,  4],
#         [10,  8, -1,  4],
#         [11,  9, -1,  4],
#         [12, 10, -1,  4],
#         [13, 11, -1,  4],
#         [14, 12, -1,  4],
#         [15, 13, -1,  4],
#         [16, 14, -1,  4],
#         [17, 15, -1,  4],
#         [18, 16, -1,  4],
#         [19, 17, -1,  4],
#         [20, 18, -1,  4],
#         [-1, 19, -1,  4],
#         [-1,  4, -1, -1]]], dtype=int32)

# %%
heirarchy.shape
# Out:
# (1, 22, 4)

# %%
externalContour=np.zeros(demoImage.shape)

# %%
for i in range(len(contour)):
    if heirarchy[0,i,3]==-1:
        cv2.drawContours(externalContour,contour,i,255,-1)

# %%
plt.imshow(blackbackground,cmap="gray")

# %%
internalContour=np.zeros(demoImage.shape)
for i in range(len(contour)):
    if heirarchy[0,i,3]!=-1:
        cv2.drawContours(internalContour,contour,i,255,-1)

# %%
plt.imshow(internalContour,cmap="gray")

# %%
#lets print specific internal contour
oneInternalContour=np.zeros(demoImage.shape)
for i in range(len(contour)):
    if heirarchy[0,i,3]==4:
        cv2.drawContours(oneInternalContour,contour,i,255,-1)
plt.imshow(oneInternalContour,cmap="gray")
