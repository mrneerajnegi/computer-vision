# %%
pip install opencv-python
# Out:
# ...
#      |████████████████████████████████| 46.0 MB 3.7 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import cv2

# %%
img_cv=cv2.imread("../Computer-Vision-with-Python/DATA/00-puppy.jpg")

# %%
type(img_cv)
# Out:
# numpy.ndarray

# %%
plt.imshow(img_cv)

# %%
# matplot default color coding R G B
# cv2 default color coding B G R

# %%
img_cv=cv2.cvtColor(img_cv,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img_cv)

# %%
img_cv.shape
# Out:
# (1300, 1950, 3)

# %%
img_gray=cv2.imread("../Computer-Vision-with-Python/DATA/00-puppy.jpg",cv2.IMREAD_GRAYSCALE)
img_gray.shape
# Out:
# (1300, 1950)

# %%
plt.imshow(img_gray,cmap="gray")

# %%
re_sized_image=cv2.resize(img_gray,(1500,1000))

# %%
re_sized_image.shape
# Out:
# (1000, 1500)

# %%
plt.imshow(re_sized_image)

# %%
w_ratio=0.5
h_ratio=0.8

# %%
ratio_img=cv2.resize(img_cv,(0,0),img_cv,w_ratio,h_ratio)

# %%
ratio_img.shape
# Out:
# (1040, 975, 3)

# %%
plt.imshow(ratio_img)

# %%
flipped_img=cv2.flip(img_cv,0)
plt.imshow(flipped_img)

# %%
flipped_img=cv2.flip(img_cv,1)
plt.imshow(flipped_img)

# %%
flipped_img=cv2.cvtColor(flipped_img,cv2.COLOR_BGR2RGB)
cv2.imwrite("abc.jpg",flipped_img)
# Out:
# True

# %%
plt.figure(figsize=(20,20))
plt.imshow(img_cv)
